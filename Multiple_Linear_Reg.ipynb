# %% [markdown]
# <a href="https://colab.research.google.com/github/sudeeraattanayake/Machine-Learning/blob/main/Multiple_Linear_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #import lib

# %% [markdown]
# #import dataset

# %% [markdown]
# #Encoding Categorical data

# %% [markdown]
# #splitting the dataset into training and test set
