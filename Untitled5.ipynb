# %% [markdown]
# <a href="https://colab.research.google.com/github/sudeeraattanayake/Machine-Learning/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #import the lib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #import the dataset

# %%
dataset = pd.read_csv('/content/Salary_Data.csv')

# %%
X = dataset.iloc[:, :1].values
y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# #splitting the dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
print(X_train)
# Out:
# [[ 4. ]
#  [ 4.5]
#  [ 4. ]
#  [ 5.9]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [10.3]
#  [ 3.7]
#  [ 3. ]
#  [ 9. ]
#  [ 6. ]
#  [ 3.2]
#  [ 2.2]
#  [10.5]
#  [ 3.2]
#  [ 6.8]
#  [ 4.1]
#  [ 1.5]
#  [ 2. ]
#  [ 8.2]
#  [ 7.9]
#  [ 1.1]
#  [ 4.9]]

# %%
print(X_test)
# Out:
# [[5.3]
#  [5.1]
#  [7.1]
#  [2.9]
#  [1.3]
#  [9.6]]

# %%
print(y_train)
# Out:
# [ 55794.  61111.  56957.  81363.  63218. 116969. 109431. 122391.  57189.
#   60150. 105582.  93940.  64445.  39891. 121872.  54445.  91738.  57081.
#   37731.  43525. 113812. 101302.  39343.  67938.]

# %% [markdown]
# #training the simple linear reg model on the trining set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #predicting the test set result

# %%
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [ 75353.84047273  73414.76743839  92805.49778175  52084.96406069
#   36572.379786   117043.91071096]

# %%
for predicted, actual in zip(y_pred, y_test):
  print(f"Predicted: {predicted}, Actual: {actual:}")
# Out:
# Predicted: 75353.84047272863, Actual: 83088.0
# Predicted: 73414.76743839243, Actual: 66029.0
# Predicted: 92805.49778175447, Actual: 98273.0
# Predicted: 52084.96406069418, Actual: 56642.0
# Predicted: 36572.379786004545, Actual: 46205.0
# Predicted: 117043.91071095703, Actual: 112635.0

# %% [markdown]
# #visualising the trainig set result

# %%
plt.title("Salary vs Experience (Training Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.scatter(X_train, y_train, color = "red")
plt.plot(X_train, regressor.predict(X_train), color = "blue")
plt.show()

# %% [markdown]
# #visualising the test set result

# %%
plt.title("Salary vs Experience (Test Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.scatter(X_test, y_test, color = "red")
plt.plot(X_train, regressor.predict(X_train), color = "blue")
plt.show()
